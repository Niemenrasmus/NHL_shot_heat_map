# %%
from helpers import pull_nhl_api_data, get_shot_and_goal_coordinates, \
                    normalize_coordinates, plot_shot_frequency_and_efficiency, plot_player_shooting_efficiency

# %%
event_data = get_shot_and_goal_coordinates(2019, 'all')

# %%
# Normalizing shot coordinates
all_league_data = normalize_coordinates(event_data)

# %%
# Plotting shot frequency for league-wide
plot_shot_frequency_and_efficiency(*all_league_data)

# %%
event_data = get_shot_and_goal_coordinates(2019, 'Teuvo Teravainen')

# %%
player_data = normalize_coordinates(event_data)
plot_shot_frequency_and_efficiency(*player_data)

# %%
plot_player_shooting_efficiency(all_league_data, player_data)
